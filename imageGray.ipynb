# %%
import urllib.request
import PIL
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
urllib.request.urlretrieve("https://github.com/Shikha23K/CNN/blob/main/abstract.jpg?raw=true","abstract.jpg")

# %%
img=plt.imread("abstract.jpg")

# %%
plt.imshow(img)

# %% [markdown]
# Each image has 3 channels R,G,B and s ome image has fourth is not imformative if there is 4 then

# %%
#im2=img[:,:,:3]
#im2.shape

# %%
img.shape
# Out:
# (2006, 1129, 3)

# %%
#change intensity of Red channel
R=img[:,:,0]
G=img[:,:,1]
B=img[:,:,2]

# %%
R.shape
# Out:
# (2006, 1129)

# %%
plt.imshow(B,cmap='gray')

# %%
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(10,15))
ax1.imshow(R,cmap='gray')
ax2.imshow(G,cmap='gray')
ax3.imshow(B,cmap='gray')

# %%
im2=img.copy()

# %%
#Make image more blueish
im2[:,:,2]=255

# %%
plt.imshow(im2)

# %%
im3=img.copy()
im3[200:600,100:600,0]=200
im3[300:800,300:600,1]=250
im3[100:1200,100:1200,2]=200

# %%
plt.imshow(im3)

# %%
imgray=.333*R+.333*G+.333*B
plt.imshow(imgray,cmap='gray')

# %%
imgray=0.2989*R+.5870*G+.1140*B
plt.imshow(imgray,cmap='gray')

# %%
import cv2
imc=img.copy()

# %%
imCV2=cv2.cvtColor(imc,cv2.COLOR_RGB2GRAY)
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,15))
ax1.imshow(imgray,cmap='gray')
ax2.imshow(imCV2,cmap='gray')

# %% [markdown]
# Image bluring/ Smoothing
